# %%
# !pip install -U albumentations
# Out:
# Requirement already satisfied: albumentations in /home/bendu/anaconda3/envs/wsl_tf_p31012/lib/python3.10/site-packages (1.3.1)
# Requirement already satisfied: numpy>=1.11.1 in /home/bendu/.local/lib/python3.10/site-packages (from albumentations) (1.26.3)
# Requirement already satisfied: scipy>=1.1.0 in /home/bendu/.local/lib/python3.10/site-packages (from albumentations) (1.11.4)
# Requirement already satisfied: scikit-image>=0.16.1 in /home/bendu/anaconda3/envs/wsl_tf_p31012/lib/python3.10/site-packages (from albumentations) (0.22.0)
# Requirement already satisfied: PyYAML in /home/bendu/anaconda3/envs/wsl_tf_p31012/lib/python3.10/site-packages (from albumentations) (6.0.1)
# Requirement already satisfied: qudida>=0.0.4 in /home/bendu/anaconda3/envs/wsl_tf_p31012/lib/python3.10/site-packages (from albumentations) (0.0.4)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /home/bendu/anaconda3/envs/wsl_tf_p31012/lib/python3.10/site-packages (from albumentations) (4.9.0.80)
# Requirement already satisfied: scikit-learn>=0.19.1 in /home/bendu/.local/lib/python3.10/site-packages (from qudida>=0.0.4->albumentations) (1.3.2)
# Requirement already satisfied: typing-extensions in /home/bendu/.local/lib/python3.10/site-packages (from qudida>=0.0.4->albumentations) (4.9.0)
# Requirement already satisfied: networkx>=2.8 in /home/bendu/anaconda3/envs/wsl_tf_p31012/lib/python3.10/site-packages (from scikit-image>=0.16.1->albumentations) (3.2.1)
# Requirement already satisfied: pillow>=9.0.1 in /home/bendu/.local/lib/python3.10/site-packages (from scikit-image>=0.16.1->albumentations) (10.2.0)
# Requirement already satisfied: imageio>=2.27 in /home/bendu/anaconda3/envs/wsl_tf_p31012/lib/python3.10/site-packages (from scikit-image>=0.16.1->albumentations) (2.34.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/bendu/anaconda3/envs/wsl_tf_p31012/lib/python3.10/site-packages (from scikit-image>=0.16.1->albumentations) (2024.2.12)
# Requirement already satisfied: packaging>=21 in /home/bendu/.local/lib/python3.10/site-packages (from scikit-image>=0.16.1->albumentations) (23.2)
# Requirement already satisfied: lazy_loader>=0.3 in /home/bendu/anaconda3/envs/wsl_tf_p31012/lib/python3.10/site-packages (from scikit-image>=0.16.1->albumentations) (0.3)
# Requirement already satisfied: joblib>=1.1.1 in /home/bendu/.local/lib/python3.10/site-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/bendu/.local/lib/python3.10/site-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations) (3.2.0)

# %%
from tensorflow.keras.preprocessing.image import load_img
import albumentations as A

import numpy as np
import matplotlib.pyplot as plt

# %%
image = load_img('image2.jpg')

# %%
def visualize(image):
    plt.figure(figsize=(3, 3))
    plt.axis('off')
    plt.imshow(image)

# %%
img = np.array(image)
visualize(img)

# %%
def transform_vis(transform):
    visualize(transform(image=img)['image'])

# %%
transform = A.HorizontalFlip(p=0.5)
transform_vis(transform=transform)

# %%
transform = A.ShiftScaleRotate(p=0.5)
transform_vis(transform=transform)
